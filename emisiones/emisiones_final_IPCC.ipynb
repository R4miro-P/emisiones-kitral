# %%
import rasterio
import numpy as np
import os
import pandas as pd

#se crea funcion que calcula sfb a partir de Ros.
def surface_fuel_consumed_vectorized(fuels, ros):
    
    #Calcula la fraccion de combustible consumido en superficie a partir de los raster de combustible y ROS
    
    sfc = np.zeros_like(fuels, dtype=np.float32)
    # Condition 1: 0 < fuels < 6
    idx1 = (fuels > 0) & (fuels < 6)
    sfc[idx1] = 1 - np.exp(-0.1 * ros[idx1])
    # Condition 2: 5 < fuels < 14
    idx2 = (fuels > 5) & (fuels < 14)
    sfc[idx2] = 1 - np.exp(-0.06 * ros[idx2])
    # Condition 3: 13 < fuels < 18
    idx3 = (fuels > 13) & (fuels < 18)
    sfc[idx3] = 1 - np.exp(-0.1 * ros[idx3])
    # Condition 4: fuels > 17
    idx4 = fuels > 17
    sfc[idx4] = 1 - np.exp(-0.06 * ros[idx4])
    return sfc

#Se crea una funcion que recibe un raster de ros y uno de cargas y calcula la fraccion consumida en superficie. Notar si ROS=0 sfb=0
def generate_surface_fraction_burned(ros_asc_path, output_folder):
    """
    Generates an ASCII grid for surface fraction burned (SFB) using a given ROS ASC file.
    Uses a fixed fuels raster and writes the output to output_folder.
    Returns the path to the generated SFB ASC file.
    """
    fuels_raster = "/home/ramiro/on-boarding/kitral/Kitral/Portillo-asc/fuels.asc"
    
    # Ensure the output folder exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Construct an output file name based on the ROS file name.
    ros_basename = os.path.basename(ros_asc_path)
    output_asc = os.path.join(output_folder, f"surface_fraction_burned_{ros_basename}")
    
    # Read the fuels raster.
    with rasterio.open(fuels_raster) as src:
        fuels = src.read(1)
        profile = src.profile.copy()
    
    # Read the current ROS file.
    with rasterio.open(ros_asc_path) as src:
        ros = src.read(1)
    
    if fuels.shape != ros.shape:
        raise ValueError(f"Fuels and ROS rasters must have the same dimensions. Got {fuels.shape} and {ros.shape}.")
    
    # Calculate the SFB array using your vectorized function (assumed defined elsewhere).
    sfc_array = surface_fuel_consumed_vectorized(fuels, ros)
    
    # Update profile for ASCII grid output.
    profile.update(driver="AAIGrid", dtype=rasterio.float32, nodata=0)
    
    # Write out the SFB ASC file.
    with rasterio.open(output_asc, "w", **profile) as dst:
        dst.write(sfc_array, 1)
    
    print(f"SFB raster saved to: {output_asc}")
    return output_asc

#Se crea un raster de Fuel Load en Superficie
def generate_fuel_load_raster():

    # 1. Read the CSV containing (fuel code -> fuel load)
    fuel_load_csv = "/home/ramiro/Emisiones/lookup_ramiro.csv"
    fuel_column = "Fuel Code"
    fuel_load_column = "fl"

    df_fuel_load = pd.read_csv(fuel_load_csv, sep=";")
    print(df_fuel_load.columns)

    # Create a dictionary {fuel_code: fuel_load}
    code_to_fuel_load = dict(zip(df_fuel_load[fuel_column],
                                df_fuel_load[fuel_load_column]))

    # 2. Paths to input (fuel-code) raster and output (fuel-load) ASCII
    input_raster = "/home/ramiro/on-boarding/kitral/Kitral/Portillo-asc/fuels.asc"
    output_raster = "/home/ramiro/Emisiones/fuel_load.asc"

    # 3. Open the input raster
    with rasterio.open(input_raster) as src:
        raster_data = src.read(1)      # Read the first band as a NumPy array
        profile = src.profile.copy()   # Copy the metadata (profile)

    # 4. Create an empty array (float32) to store fuel loads
    fuel_load_raster = np.zeros_like(raster_data, dtype=np.float32)

    # 5. Replace each fuel code with the corresponding fuel load
    for code, fuel_load in code_to_fuel_load.items():
        # Where the raster_data equals "code", set the output to the fuel load
        fuel_load_raster[raster_data == code] = fuel_load

    # 6. Update the profile for ASCII output
    #    - Specify driver='AAIGrid' so rasterio writes Arc/Info ASCII
    #    - Make sure dtype and nodata are set appropriately
    profile.update(
        driver="AAIGrid",
        dtype=rasterio.float32,
        nodata=0
    )

    # 7. Write the output ASCII grid
    with rasterio.open(output_raster, "w", **profile) as dst:
        dst.write(fuel_load_raster, 1)

    print(f"ASCII grid with fuel loads created: {output_raster}")
    return output_raster

def emisiones_generadas_vectorized(fuels, fuel_load, sfb):
    """
    Calcula las emisiones generadas (en CO2eq) para cada pixel a partir
    de los arrays: combustibles (fuels), carga de combustible (fuel_load) y
    la fracción quemada (sfb). Se espera que todos tengan la misma dimensión.
    """
    # Optional: check that all arrays have the same shape
    if fuels.shape != fuel_load.shape or fuels.shape != sfb.shape:
        raise ValueError("All input arrays must have the same dimensions.")
    
    # Calcular la carga consumida
    fuel_consumed = np.where(sfb!=0,fuel_load * 0.45,0)
    
    # Inicializar el array de emisiones con ceros (mismo shape que fuels)
    emisiones = np.zeros_like(fuels, dtype=np.float32)
    
    # Condiciones para Pastizales: (fuels > 0) y (fuels < 6)
    idx1 = (fuels > 0) & (fuels < 6)
    eCO2 = 1613 * fuel_consumed[idx1] * 10**(-2)
    eCH4 = 2.3 * fuel_consumed[idx1] * 10**(-2)
    eN2O = 0.21 * fuel_consumed[idx1] * 10**(-2)
    emisiones[idx1] = eCO2 + eCH4 * 27 + eN2O * 273

    # Condiciones para Matorrales: (fuels > 5) y (fuels < 14)
    idx2 = (fuels > 5) & (fuels < 14)
    eCO2 = 1613 * fuel_consumed[idx2] * 10**(-2)
    eCH4 = 2.3 * fuel_consumed[idx2] * 10**(-2)
    eN2O = 0.21 * fuel_consumed[idx2] * 10**(-2)
    emisiones[idx2] = eCO2 + eCH4 * 27 + eN2O * 273

    # Condiciones para Arboles: (fuels > 13) y (fuels < 18)
    idx3 = (fuels > 13) & (fuels < 18)
    eCO2 = 1569 * fuel_consumed[idx3] * 10**(-2)
    eCH4 = 4.7 * fuel_consumed[idx3] * 10**(-2)
    eN2O = 0.26 * fuel_consumed[idx3] * 10**(-2)
    emisiones[idx3] = eCO2 + eCH4 * 27 + eN2O * 273

    # Condiciones para Arboles de plantación: fuels > 17
    idx4 = fuels > 17
    eCO2 = 1569 * fuel_consumed[idx4] * 10**(-2)
    eCH4 = 4.7 * fuel_consumed[idx4] * 10**(-2)
    eN2O = 0.26 * fuel_consumed[idx4] * 10**(-2)
    emisiones[idx4] = eCO2 + eCH4 * 27 + eN2O * 273

    return emisiones


def generate_emisiones_generadas_raster(fuels_raster_path, fuel_load_raster, sfb_raster_path, output_folder):
    """
    Generates an ASCII emissions raster using the fuels, fuel load, and SFB rasters.
    Saves the output ASC file to the specified output folder with a unique name.
    Returns the path to the generated emissions ASC file.
    """
    # Ensure output folder exists.
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Use the base name of the SFB file to construct a unique emissions file name.
    sfb_basename = os.path.basename(sfb_raster_path)
    name, _ = os.path.splitext(sfb_basename)
    output_raster = os.path.join(output_folder, f"emisiones_generadas_{name}.asc")
    
    # Read fuels raster.
    with rasterio.open(fuels_raster_path) as src:
        fuels = src.read(1)
        profile = src.profile.copy()
    
    # Read fuel load raster.
    with rasterio.open(fuel_load_raster) as src:
        fuel_load = src.read(1)
    
    # Read SFB raster.
    with rasterio.open(sfb_raster_path) as src:
        sfb = src.read(1)
    
    # Verify dimensions match.
    if fuels.shape != fuel_load.shape or fuels.shape != sfb.shape:
        raise ValueError("The rasters (fuels, fuel load, and sfb) must have the same dimensions.")
    
    # Calculate emissions using the vectorized function.
    emisiones_array = emisiones_generadas_vectorized(fuels, fuel_load, sfb)
    
    profile.update(driver="AAIGrid", dtype=rasterio.float32, nodata=0)
    
    with rasterio.open(output_raster, "w", **profile) as dst:
        dst.write(emisiones_array, 1)
    
    print(f"Emisiones generadas raster saved to: {output_raster}")
    return output_raster


    
#Se crea una funcion que suma el total de emisiones generadas.
def sum_raster_values(raster_path):
    
    #Suma los valores de cada pixel en un raster (ignora los nodata si estan masked).
    
    with rasterio.open(raster_path) as src:
        data = src.read(1, masked=True)
        total_sum = data.sum()
    return total_sum

def average_pixel_value(raster_path):
    """
    Computes the average value of all valid pixels in an Arc/Info ASCII Grid (ASC) file.
    It uses the raster's nodata value to ignore invalid pixels.
    """
    with rasterio.open(raster_path) as src:
        # Read the first band as a masked array so that nodata values are ignored.
        data = src.read(1, masked=True)
        # Calculate the mean of the valid (non-masked) values.
        average = np.ma.mean(data)
    return average

# %%
# -------------------------------------------------------------------
# MASTER MAIN FUNCTION
# -------------------------------------------------------------------


def main():
    # Generate the fuel load raster once (assumed constant).
    fuel_load_raster = generate_fuel_load_raster()  # This function must return the output file path.
    
    # Fixed fuels raster path.
    fuels_raster_path = "/home/ramiro/on-boarding/kitral/Kitral/Portillo-asc/fuels.asc"
    
    # Folder containing the ROS ASC files.
    ros_folder = "/home/ramiro/Emisiones/50sim/ROS/"
    # Folder to store generated SFB rasters.
    sfb_output_folder = "/home/ramiro/Emisiones/50sim/SFB_ipcc/"
    # Folder to store geneated emissions rasters.
    emissions_output_folder = "/home/ramiro/Emisiones/50sim/Emisiones_ipcc/"
    
    # List all ROS ASC files in the folder.
    ros_files = [os.path.join(ros_folder, f) for f in os.listdir(ros_folder) if f.endswith('.asc')]
    if not ros_files:
        raise FileNotFoundError("No ROS ASC files found in the specified folder.")
    
    # Lists to store emissions raster paths and the corresponding sum values.
    emisiones_sums = []
    average_value = []
    
    # Loop over each ROS file.
    for ros_file in ros_files:
        print(f"\nProcessing ROS file: {ros_file}")
        
        # Step 1: Generate surface fraction burned raster for the current ROS file.
        sfb_raster = generate_surface_fraction_burned(ros_file, sfb_output_folder)
        
        # Step 2: Generate emissions raster using fuels.asc, fuel load, and the current SFB raster.
        emisiones_generadas_raster = generate_emisiones_generadas_raster(
            fuels_raster_path, fuel_load_raster, sfb_raster, emissions_output_folder
        )
        
        # Step 3: Sum the emissions raster values.
        emis_sum = sum_raster_values(emisiones_generadas_raster)

        avg_value = average_pixel_value(sfb_raster)

        
        # Store the results.
        emisiones_sums.append(emis_sum)
        average_value.append(avg_value)
        
        print(f"Sum of emisiones_generadas for {os.path.basename(ros_file)}: {emis_sum}")
        print(f"Average pixel value for {os.path.basename(ros_file)}: {avg_value}")
    
    print("\nList of emissions sums: ",emisiones_sums)
    print("\nlist of average pixel values: ",average_value)

# -------------------------------------------------------------------
# Execute master main if run as a script
# -------------------------------------------------------------------
if __name__ == "__main__":
    main()
# Out:
# Index(['Fuel Code', 'fl', 'cbd', 'cbh', 'cfl'], dtype='object')
# ASCII grid with fuel loads created: /home/ramiro/Emisiones/fuel_load.asc
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_36.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_36.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_36.asc
# Sum of emisiones_generadas for band_36.asc: 225886.75
# Average pixel value for band_36.asc: 0.2589570785507064
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_37.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_37.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_37.asc
# Sum of emisiones_generadas for band_37.asc: 208344.46875
# Average pixel value for band_37.asc: 0.3212461786075961
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_12.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_12.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_12.asc
# Sum of emisiones_generadas for band_12.asc: 315583.75
# Average pixel value for band_12.asc: 0.24749150746881707
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_3.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_3.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_3.asc
# Sum of emisiones_generadas for band_3.asc: 242647.953125
# Average pixel value for band_3.asc: 0.24464464622021723
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_23.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_23.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_23.asc
# Sum of emisiones_generadas for band_23.asc: 261204.625
# Average pixel value for band_23.asc: 0.22010250797881442
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_39.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_39.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_39.asc
# Sum of emisiones_generadas for band_39.asc: 105060.40625
# Average pixel value for band_39.asc: 0.21491227885269168
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_9.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_9.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_9.asc
# Sum of emisiones_generadas for band_9.asc: 341519.96875
# Average pixel value for band_9.asc: 0.2331912443914117
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_43.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_43.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_43.asc
# Sum of emisiones_generadas for band_43.asc: 331921.28125
# Average pixel value for band_43.asc: 0.26418329367951604
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_45.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_45.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_45.asc
# Sum of emisiones_generadas for band_45.asc: 132948.125
# Average pixel value for band_45.asc: 0.20032153352995313
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_10.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_10.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_10.asc
# Sum of emisiones_generadas for band_10.asc: 12771.912109375
# Average pixel value for band_10.asc: 0.06275485289420966
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_33.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_33.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_33.asc
# Sum of emisiones_generadas for band_33.asc: 372312.90625
# Average pixel value for band_33.asc: 0.23263908079469642
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_15.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_15.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_15.asc
# Sum of emisiones_generadas for band_15.asc: 292311.96875
# Average pixel value for band_15.asc: 0.22600418287285406
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_7.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_7.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_7.asc
# Sum of emisiones_generadas for band_7.asc: 265127.5
# Average pixel value for band_7.asc: 0.21525249854984646
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_20.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_20.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_20.asc
# Sum of emisiones_generadas for band_20.asc: 327207.8125
# Average pixel value for band_20.asc: 0.2550658006256866
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_6.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_6.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_6.asc
# Sum of emisiones_generadas for band_6.asc: 181012.984375
# Average pixel value for band_6.asc: 0.23175908815873955
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_13.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_13.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_13.asc
# Sum of emisiones_generadas for band_13.asc: 268738.65625
# Average pixel value for band_13.asc: 0.272464461839731
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_28.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_28.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_28.asc
# Sum of emisiones_generadas for band_28.asc: 88175.03125
# Average pixel value for band_28.asc: 0.2836897538599831
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_34.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_34.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_34.asc
# Sum of emisiones_generadas for band_34.asc: 394723.6875
# Average pixel value for band_34.asc: 0.2682141653850688
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_4.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_4.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_4.asc
# Sum of emisiones_generadas for band_4.asc: 260992.515625
# Average pixel value for band_4.asc: 0.21133113891285119
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_19.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_19.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_19.asc
# Sum of emisiones_generadas for band_19.asc: 207605.15625
# Average pixel value for band_19.asc: 0.18802262424685567
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_50.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_50.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_50.asc
# Sum of emisiones_generadas for band_50.asc: 278309.0
# Average pixel value for band_50.asc: 0.2672584345284559
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_24.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_24.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_24.asc
# Sum of emisiones_generadas for band_24.asc: 366708.5
# Average pixel value for band_24.asc: 0.24033512231033466
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_18.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_18.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_18.asc
# Sum of emisiones_generadas for band_18.asc: 85844.2890625
# Average pixel value for band_18.asc: 0.27674967769959435
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_30.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_30.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_30.asc
# Sum of emisiones_generadas for band_30.asc: 282652.34375
# Average pixel value for band_30.asc: 0.1909676926239455
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_29.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_29.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_29.asc
# Sum of emisiones_generadas for band_29.asc: 346530.875
# Average pixel value for band_29.asc: 0.27008312803245205
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_16.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_16.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_16.asc
# Sum of emisiones_generadas for band_16.asc: 197597.265625
# Average pixel value for band_16.asc: 0.3159024077135971
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_22.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_22.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_22.asc
# Sum of emisiones_generadas for band_22.asc: 340044.0625
# Average pixel value for band_22.asc: 0.2720656278989516
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_40.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_40.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_40.asc
# Sum of emisiones_generadas for band_40.asc: 191909.375
# Average pixel value for band_40.asc: 0.18929418918155588
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_32.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_32.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_32.asc
# Sum of emisiones_generadas for band_32.asc: 270351.4375
# Average pixel value for band_32.asc: 0.29475005387931036
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_14.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_14.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_14.asc
# Sum of emisiones_generadas for band_14.asc: 330031.03125
# Average pixel value for band_14.asc: 0.2558126947007354
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_11.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_11.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_11.asc
# Sum of emisiones_generadas for band_11.asc: 218237.234375
# Average pixel value for band_11.asc: 0.239307804712655
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_41.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_41.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_41.asc
# Sum of emisiones_generadas for band_41.asc: 359026.71875
# Average pixel value for band_41.asc: 0.27730847801889147
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_2.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_2.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_2.asc
# Sum of emisiones_generadas for band_2.asc: 167907.53125
# Average pixel value for band_2.asc: 0.23390209153215047
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_5.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_5.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_5.asc
# Sum of emisiones_generadas for band_5.asc: 131987.203125
# Average pixel value for band_5.asc: 0.2265186666995845
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_25.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_25.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_25.asc
# Sum of emisiones_generadas for band_25.asc: 96940.328125
# Average pixel value for band_25.asc: 0.24173754495287697
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_44.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_44.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_44.asc
# Sum of emisiones_generadas for band_44.asc: 190377.125
# Average pixel value for band_44.asc: 0.23564568451943071
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_26.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_26.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_26.asc
# Sum of emisiones_generadas for band_26.asc: 190895.21875
# Average pixel value for band_26.asc: 0.2190678914388021
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_48.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_48.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_48.asc
# Sum of emisiones_generadas for band_48.asc: 269706.375
# Average pixel value for band_48.asc: 0.2951683359435861
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_38.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_38.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_38.asc
# Sum of emisiones_generadas for band_38.asc: 239637.125
# Average pixel value for band_38.asc: 0.20628857887434182
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_31.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_31.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_31.asc
# Sum of emisiones_generadas for band_31.asc: 138400.90625
# Average pixel value for band_31.asc: 0.1905422658187676
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_46.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_46.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_46.asc
# Sum of emisiones_generadas for band_46.asc: 130637.9609375
# Average pixel value for band_46.asc: 0.24962318497474748
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_21.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_21.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_21.asc
# Sum of emisiones_generadas for band_21.asc: 285273.1875
# Average pixel value for band_21.asc: 0.22417670002019835
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_27.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_27.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_27.asc
# Sum of emisiones_generadas for band_27.asc: 205602.734375
# Average pixel value for band_27.asc: 0.26259066040752926
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_42.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_42.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_42.asc
# Sum of emisiones_generadas for band_42.asc: 355182.78125
# Average pixel value for band_42.asc: 0.2564652138810446
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_1.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_1.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_1.asc
# Sum of emisiones_generadas for band_1.asc: 326271.125
# Average pixel value for band_1.asc: 0.29013769734940376
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_47.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_47.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_47.asc
# Sum of emisiones_generadas for band_47.asc: 14558.046875
# Average pixel value for band_47.asc: 0.06911844095513081
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_49.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_49.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_49.asc
# Sum of emisiones_generadas for band_49.asc: 115726.96875
# Average pixel value for band_49.asc: 0.25079385935682436
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_8.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_8.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_8.asc
# Sum of emisiones_generadas for band_8.asc: 78334.9453125
# Average pixel value for band_8.asc: 0.1795899451583593
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_17.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_17.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_17.asc
# Sum of emisiones_generadas for band_17.asc: 194592.8125
# Average pixel value for band_17.asc: 0.26977578319415196
#
# Processing ROS file: /home/ramiro/Emisiones/50sim/ROS/band_35.asc
# SFB raster saved to: /home/ramiro/Emisiones/50sim/SFB_ipcc/surface_fraction_burned_band_35.asc
# Emisiones generadas raster saved to: /home/ramiro/Emisiones/50sim/Emisiones_ipcc/emisiones_generadas_surface_fraction_burned_band_35.asc
# Sum of emisiones_generadas for band_35.asc: 377139.125
# Average pixel value for band_35.asc: 0.26732729499182933
#
# List of emissions sums:  [np.float32(225886.75), np.float32(208344.47), np.float32(315583.75), np.float32(242647.95), np.float32(261204.62), np.float32(105060.41), np.float32(341519.97), np.float32(331921.28), np.float32(132948.12), np.float32(12771.912), np.float32(372312.9), np.float32(292311.97), np.float32(265127.5), np.float32(327207.8), np.float32(181012.98), np.float32(268738.66), np.float32(88175.03), np.float32(394723.7), np.float32(260992.52), np.float32(207605.16), np.float32(278309.0), np.float32(366708.5), np.float32(85844.29), np.float32(282652.34), np.float32(346530.88), np.float32(197597.27), np.float32(340044.06), np.float32(191909.38), np.float32(270351.44), np.float32(330031.03), np.float32(218237.23), np.float32(359026.72), np.float32(167907.53), np.float32(131987.2), np.float32(96940.33), np.float32(190377.12), np.float32(190895.22), np.float32(269706.38), np.float32(239637.12), np.float32(138400.9), np.float32(130637.96), np.float32(285273.2), np.float32(205602.73), np.float32(355182.78), np.float32(326271.12), np.float32(14558.047), np.float32(115726.97), np.float32(78334.945), np.float32(194592.81), np.float32(377139.12)]
#
# list of average pixel values:  [np.float64(0.2589570785507064), np.float64(0.3212461786075961), np.float64(0.24749150746881707), np.float64(0.24464464622021723), np.float64(0.22010250797881442), np.float64(0.21491227885269168), np.float64(0.2331912443914117), np.float64(0.26418329367951604), np.float64(0.20032153352995313), np.float64(0.06275485289420966), np.float64(0.23263908079469642), np.float64(0.22600418287285406), np.float64(0.21525249854984646), np.float64(0.2550658006256866), np.float64(0.23175908815873955), np.float64(0.272464461839731), np.float64(0.2836897538599831), np.float64(0.2682141653850688), np.float64(0.21133113891285119), np.float64(0.18802262424685567), np.float64(0.2672584345284559), np.float64(0.24033512231033466), np.float64(0.27674967769959435), np.float64(0.1909676926239455), np.float64(0.27008312803245205), np.float64(0.3159024077135971), np.float64(0.2720656278989516), np.float64(0.18929418918155588), np.float64(0.29475005387931036), np.float64(0.2558126947007354), np.float64(0.239307804712655), np.float64(0.27730847801889147), np.float64(0.23390209153215047), np.float64(0.2265186666995845), np.float64(0.24173754495287697), np.float64(0.23564568451943071), np.float64(0.2190678914388021), np.float64(0.2951683359435861), np.float64(0.20628857887434182), np.float64(0.1905422658187676), np.float64(0.24962318497474748), np.float64(0.22417670002019835), np.float64(0.26259066040752926), np.float64(0.2564652138810446), np.float64(0.29013769734940376), np.float64(0.06911844095513081), np.float64(0.25079385935682436), np.float64(0.1795899451583593), np.float64(0.26977578319415196), np.float64(0.26732729499182933)]
